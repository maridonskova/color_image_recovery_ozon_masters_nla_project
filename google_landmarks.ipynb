# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from itertools import product, cycle
from functools import reduce
from operator import mul

from tqdm.notebook import tqdm

import requests
import shutil

import image_recovery.linalg as irl
import image_recovery.imglib as iri

import glob
import os

import cv2

SEED = 17

# %% [markdown]
# ## Downloading images

# %%
CSV_PATH = "google_train.csv"
SAVE_PATH = "google_landmarks"
SAVED_URLS_FILE = "google_landmarks.txt"

max_resolution = (640, 480)
imgs_to_download = 100

with open(CSV_PATH, "r") as fh:
    urls = [x.split(",")[1].strip("\'\"") for x in fh.readlines()[1:]]
    
# ================
# CAREFUL! THIS CODE ERASES ALL THE FILES IN DIRECTORY!

for ximg in glob.glob(os.path.join(SAVE_PATH, "*")):
    os.remove(ximg)
    
# ================

np.random.seed(SEED)
    
with open(SAVED_URLS_FILE, "w") as fh:
    ix = 0
    idxs = iter(np.random.permutation(len(urls)))
    
    while ix < imgs_to_download:
        idx = next(idxs)
        
        try:
            req = requests.get(urls[idx], stream=True)
            
            if req.status_code == 200:
                print(f"{ix + 1}. Successfully downloaded {urls[idx]}")

                if urls[idx].endswith("jpg"):
                    filepath = os.path.join(SAVE_PATH, f"img{idx}.jpg")
                else:
                    filepath = os.path.join(SAVE_PATH, f"img{idx}.png")

                with open(filepath, "wb") as fimg:
                    req.raw.decode_content = True
                    shutil.copyfileobj(req.raw, fimg)

                # ================

                img = cv2.imread(filepath)

                if np.prod(img.shape[:2]) > np.prod(max_resolution):
                    cft = np.sqrt(np.prod(max_resolution)/np.prod(img.shape[:2]))
                    new_shape = (int(img.shape[0]*cft), int(img.shape[1]*cft))

                    print(f"Image has resolution {img.shape[0]} x {img.shape[1]}. Shrinked to {new_shape[0]} x {new_shape[1]}")

                    new_img = cv2.resize(img, (0, 0), fx=cft, fy=cft)
                    cv2.imwrite(filepath, new_img)

                fh.write(", ".join((filepath, urls[idx])) + "\n")
                ix += 1
            else:
                print(f"Failed to download {urls[idx]}")
            
        except:
            print(f"Failed to get URL {urls[idx]}")
# Out:
# 1. Successfully downloaded https://lh3.googleusercontent.com/-z9i6VbFuOws/TCwxajH0dLI/AAAAAAAABN4/cGdCZCixLD0/s1600/
# Image has resolution 1200 x 1600. Shrinked to 480 x 640
# 2. Successfully downloaded https://lh6.googleusercontent.com/-gpM3ulJoJZc/Rs9drifk4ZI/AAAAAAAAA8Q/fb_NtsWAR90/rj/
# 3. Successfully downloaded https://lh4.googleusercontent.com/-9YxLxk5LXXM/T6VOsJzKYiI/AAAAAAAACL0/04QSGNkyNUg/s1600/
# Image has resolution 1060 x 1600. Shrinked to 451 x 680
# 4. Successfully downloaded http://lh5.ggpht.com/-oVsFDevOTaE/TKTlaN-cXPI/AAAAAAAAAeg/JlY7BXnTcdY/s1600/
# Image has resolution 1200 x 1600. Shrinked to 480 x 640
# 5. Successfully downloaded https://lh6.googleusercontent.com/-0lm0Elikcn0/TVGnvHSc2hI/AAAAAAAABFU/ta7fNfAcRg0/s1600/
# Image has resolution 1064 x 1600. Shrinked to 451 x 679
# 6. Successfully downloaded http://lh4.ggpht.com/-fd9sMTBcrCY/SWklzQexDlI/AAAAAAAAB38/wJ3J0RHG1Vg/s1600/
# Image has resolution 1074 x 1600. Shrinked to 454 x 676
# 7. Successfully downloaded http://lh3.ggpht.com/-LpyTDeGeQFI/SERTN6k_cfI/AAAAAAAAEH4/IgEelua7vVo/rj/
# 8. Successfully downloaded https://lh3.googleusercontent.com/-C0r1asBsliw/TErQzn9ORYI/AAAAAAAAC5c/LpIuoRhPcoI/s1600/
# Image has resolution 1200 x 1600. Shrinked to 480 x 640
s1600/
# Image has resolution 1200 x 1600. Shrinked to 480 x 640
# 61. Successfully downloaded https://lh6.googleusercontent.com/-2wAj4UDz4dA/UbH3rJy8poI/AAAAAAAABbc/jgAliAhAWAo/s1600/
# Image has resolution 1024 x 768. Shrinked to 640 x 480
# Failed to download http://mw2.google.com/mw-panoramio/photos/medium/4822020.jpg
# 62. Successfully downloaded https://lh6.googleusercontent.com/-uR0daANE1Oc/TDTt_Y3wGRI/AAAAAAAACW8/9HXoI0TwGy4/s1600/
# Image has resolution 1600 x 1200. Shrinked to 640 x 480
# 63. Successfully downloaded https://lh5.googleusercontent.com/--bbufeXiUZE/Ust9JG3VbiI/AAAAAAAPJ18/aX8REAUe0DM/s1600/
# 64. Successfully downloaded http://lh6.ggpht.com/-ZpASEdXYjLM/ST-j1ddlq0I/AAAAAAAAEDY/DYvBzpFMHx0/s1600/
# Image has resolution 1600 x 1200. Shrinked to 640 x 480
# 65. Successfully downloaded https://lh5.googleusercontent.com/-k92Gi3_7VKc/SgHqkuyl5SI/AAAAAAAAE8g/0KJZmhJqDzE/s1600/
# Image has resolution 1600 x 1067. Shrinked to 678 x 452
# 66. Successfully downloaded https://lh3.googleusercontent.com/-X_ZAg_Q1gyE/Sv_9hwSA5bI/AAAAAAAAAgk/Trd5IV9BAdc/s1600/
# Image has resolution 768 x 1024. Shrinked to 480 x 640
# 67. Successfully downloaded http://lh4.ggpht.com/-immTBKayjDA/Rm92_SRbo2I/AAAAAAAABO8/zUKq5MDzDs0/s1600/
# Image has resolution 1200 x 1600. Shrinked to 480 x 640
# 68. Successfully downloaded https://lh6.googleusercontent.com/-976wY-jq4rM/TAgD7-bW2LI/AAAAAAAAFPE/iZ8HLYDTVvo/s1600/
# Image has resolution 1600 x 1200. Shrinked to 640 x 480
# 69. Successfully downloaded https://lh5.googleusercontent.com/-mwY_RLhdqVg/SqCrtDwIHtI/AAAAAAAABxI/1Op4EO3uBFM/s1600/
# Image has resolution 768 x 1024. Shrinked to 480 x 640
# 70. Successfully downloaded https://lh6.googleusercontent.com/-5ZL2Vao8m58/RjYy8fiiGuI/AAAAAAAAAN4/-8pLVQaSoos/s640/
# 71. Successfully downloaded https://lh6.googleusercontent.com/-8QzQm7guC9U/ShIIMKZXZGI/AAAAAAAAAhc/AtIz73vedR4/s1600/
# Image has resolution 1200 x 1600. Shrinked to 480 x 640
# Failed to get URL None
# 72. Successfully downloaded https://lh5.googleusercontent.com/-pnmXaihvxZA/SM2IY3-U2jI/AAAAAAAABus/XOdKtjqOZ9M/s1600/
# Image has resolution 922 x 1229. Shrinked to 480 x 639
# 73. Successfully downloaded http://lh4.ggpht.com/-s6sUhOoAsW4/SDHuMcMxRAI/AAAAAAAAA04/o8MpYCBV66o/s1600/
# Image has resolution 1600 x 1067. Shrinked to 678 x 452
# 74. Successfully downloaded https://lh4.googleusercontent.com/-juXxjXobnQA/SD-1hklakfI/AAAAAAAADDM/3PzaRxUH9z8/rj/
# 75. Successfully downloaded https://lh6.googleusercontent.com/-rBavFZK3ZBo/T1KQfbhaj3I/AAAAAAAAQ8I/xev9W8tEQ04/s1600/
# Image has resolution 1067 x 1600. Shrinked to 452 x 678
# 76. Successfully downloaded https://lh3.googleusercontent.com/-rADU3S89azs/UBV8D1uKzUI/AAAAAAAAABE/Ml3is8be8Bs/s1600/
# Image has resolution 1200 x 1600. Shrinked to 480 x 640
# 77. Successfully downloaded https://lh4.googleusercontent.com/-mhv_ZlENWVI/Th329fv9P2I/AAAAAAAABKo/Wg6OdO83jz8/s1600/
# Image has resolution 720 x 540. Shrinked to 640 x 480
# 78. Successfully downloaded https://lh5.googleusercontent.com/-0voQoozgyKA/T3taVj_7YRI/AAAAAAAAAFU/0mGIAA0vPZc/s1600/
# Image has resolution 1600 x 1195. Shrinked to 641 x 478
# 79. Successfully downloaded https://lh4.googleusercontent.com/-Ab-BGusmCgA/SNFSh2CfpPI/AAAAAAAAAw0/PUKqdE6xDgk/s1600/
# Image has resolution 1600 x 1200. Shrinked to 640 x 480
#
s1600/
# Image has resolution 1600 x 1200. Shrinked to 640 x 480
# 95. Successfully downloaded https://lh3.googleusercontent.com/-6cRwYnt5BBQ/UJiLYDkSsBI/AAAAAAAAAHo/6ix-in3XZFo/s1600/
# Image has resolution 904 x 1600. Shrinked to 416 x 737
# 96. Successfully downloaded http://lh4.ggpht.com/-7l_IDI6fzv8/R3uXCsamKTI/AAAAAAAAAgQ/bwH5T2u19tA/s1600/
# Image has resolution 1198 x 1600. Shrinked to 479 x 640
# 97. Successfully downloaded http://lh6.ggpht.com/-r2rhw3BZhEU/SDWI_h0WeuI/AAAAAAAAACY/erL288SCDSA/s1600/
# 98. Successfully downloaded https://lh5.googleusercontent.com/-DlbLCKM128g/SqGOxLmP_NI/AAAAAAAAGP8/utX_c65nC20/rj/
# 99. Successfully downloaded https://lh5.googleusercontent.com/-q3M5165ZgKQ/RzXI-kT9vWI/AAAAAAAABsY/WKeK9im85_Y/s1600/
# Image has resolution 1600 x 1200. Shrinked to 640 x 480
# 100. Successfully downloaded https://lh4.googleusercontent.com/-xgg5QipwMLw/SqeBLEH8wbI/AAAAAAAACZ0/1Lc069FYLA4/s1600/

# %% [markdown]
# ## Experimenting

# %%
configs = {
    "q": [0.5],
    "reg_coef": np.logspace(-1.0, 1.0, 5),
    "rot": [5.0, 10.0, 20.0],
    "hard_rank_reduction": [True, False],
    "rank_mult": [0.8]
}

# %%
def rprod(xs):
    return reduce(mul, xs)

# %%
RESULTS_FILE = "seed17_n100.txt"

paths = glob.glob(os.path.join(SAVE_PATH, "*.png")) + glob.glob(os.path.join(SAVE_PATH, "*.jpg"))

if os.path.isfile(RESULTS_FILE):
    os.remove(RESULTS_FILE)

for (ix, ximg) in tqdm(enumerate(paths), total=len(paths)):
    img = iri.img2qm(ximg)
    tainted = (None, None)
    results = [None for _ in range(rprod(map(len, configs.values())))]
    
    for (jx, xcfg) in tqdm(enumerate(product(*list(zip(cycle((k, )), v) for (k, v) in configs.items()))), 
                           total=rprod(map(len, configs.values())), leave=False):
        cfg = dict(xcfg)
        xq = cfg.pop("q")
        
        if xq != tainted[0]:
            tainted = (xq, iri.add_random_missing_pixels(img, q=xq, mode="uniform", random_state=SEED))
            
        # ================
        
        rimg, U, _ = irl.lrqmc(mtr=tainted[1][0], mask=tainted[1][1], init_rank=100,
                               max_iter=100, rel_tol=1e-3, random_state=SEED, progress=False, **cfg)
        results[jx] = {
            **cfg,
            **{
                "img": ximg,
                "rank": U.shape[1],
                "norm": np.sqrt(np.power(rimg - img, 2).sum())
            }
        }
        
    # ================
        
    pd.DataFrame(results).to_csv(RESULTS_FILE, mode="a", header=(ix == 0))
# Out:
# HBox(children=(FloatProgress(value=0.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, max=30.0), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-fc7b1e35126b> in <module>
#      22
#      23         rimg, U, _ = irl.lrqmc(mtr=tainted[1][0], mask=tainted[1][1], init_rank=100,
# ---> 24                                max_iter=100, rel_tol=1e-3, random_state=SEED, progress=False, **cfg)
#      25         results[jx] = {
#      26             **cfg,
#
# ~/devel/nla_sem_01_project/image_recovery/linalg.py in lrqmc(mtr, mask, init_rank, reg_coef, max_iter, rel_tol, hard_rank_reduction, rot, rank_mult, return_norms, random_state, progress)
#     289                     c_rank = max(int(rank_mult*c_rank), 2)
#     290
# --> 291                 XU, XS, XVh = splin.svd(X, compute_uv=True, full_matrices=False)
#     292                 U = XU[:, :c_rank]*XS[None, :c_rank]
#     293                 V = XVh[:c_rank, :]
#
# ~/.pyenv/versions/3.6.9/envs/ozon_ml/lib/python3.6/site-packages/scipy/linalg/decomp_svd.py in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     127     # perform decomposition
#     128     u, s, v, info = gesXd(a1, compute_uv=compute_uv, lwork=lwork,
# --> 129                           full_matrices=full_matrices, overwrite_a=overwrite_a)
#     130
#     131     if info > 0:
#
# KeyboardInterrupt:
